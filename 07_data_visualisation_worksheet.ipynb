# %% [markdown]
# <a href="https://colab.research.google.com/github/dorji04/ISYS2001/blob/main/07_data_visualisation_worksheet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [raw]
# ---
# title: "Data visualisation with Python and Pandas"
# format:
#   pdf:
#       toc: false
#       colorlinks: true
#   docx:
#       toc: false
#       highlight-style: github
#   html:
#       toc: true
#       toc-expand: 2
#       embed-resources: true
# ---

# %% [markdown]
# ### Objective
# In this exercise, you will load a weather dataset into a Pandas DataFrame and create various visualisations to explore the data. Your tasks include generating a line plot, scatter plot, and bar plot, and then combining these visualisations into a multi-panel figure using subplots.
#
# ### Instructions
# Follow the steps below and answer the questions to complete the exercise.
#
# ### Prerequisites
# - Python installed with Pandas, Matplotlib libraries.
# - A CSV file. **mock_weather_data_seasonal.csv** containing weather data (e.g., temperature, humidity, precipitation).  Download this form the unit's blackboard site and *upload* to your Google Colab virtual machine.
#
# ### Tasks
#
# #### Task 1: Load the Dataset
# 1. Load the weather dataset into a Pandas DataFrame.
#    - Use the appropriate function to read the CSV file.
#    - Display the first 5 rows of the DataFrame.
#
#    **Questions:**
#    - What are the column names in your dataset?
#    - How many rows and columns does the dataset have?

# %%
import pandas as pd
df= pd.read_csv("mock_weather_data_seasonal.csv")
print(df.head()) # im using head fuction to display first 6 rows
print("OR")
df
# Out:
#          Date  Temperature   Humidity  Precipitation  DayOfYear
# 0  2024-01-01     8.139124  67.294456       9.616685          1
# 1  2024-01-02    11.660600  63.559983       6.204800          2
# 2  2024-01-03     6.518607  62.825988       3.818302          3
# 3  2024-01-04     4.763071  61.833241       7.478910          4
# 4  2024-01-05     7.655923  60.435315       0.559875          5
# OR
#            Date  Temperature   Humidity  Precipitation  DayOfYear
# 0    2024-01-01     8.139124  67.294456       9.616685          1
# 1    2024-01-02    11.660600  63.559983       6.204800          2
# 2    2024-01-03     6.518607  62.825988       3.818302          3
# 3    2024-01-04     4.763071  61.833241       7.478910          4
# 4    2024-01-05     7.655923  60.435315       0.559875          5
# ..          ...          ...        ...            ...        ...
# 361  2024-12-27     7.044578  57.973573       8.277811        362
# 362  2024-12-28     1.709481  56.769942       2.868681        363
# 363  2024-12-29     1.512058  61.914211       1.605505        364
# 364  2024-12-30     7.799821  53.118770       6.678480        365
# 365  2024-12-31     2.587605  53.948439       1.587756        366
#
# [366 rows x 5 columns]

# %% [markdown]
# A. The column names are Date, Temperature, Humidity, Precipitation and Day of year.
# B. There are 366 rows x 5 columns

# %% [markdown]
# #### Task 2: Line Plot for Temperature Trends
# 2. Generate a line plot to visualise temperature trends over time.
#    - Choose the appropriate function to plot the data.
#    - Set labels for the x-axis and y-axis.
#    - Include a title for your plot.
#
#    **Questions:**
#    - What trends do you observe in the temperature over time?
#    - Are there any noticeable patterns or anomalies?

# %%
import matplotlib.pyplot as plt

# Line plot for temperature trends
plt.figure(figsize=(10, 5))
plt.plot(df['Date'], df['Temperature'], label='Temperature', color='blue')
plt.xlabel('Date')
plt.ylabel('Temperature (°C)')  # Corrected typo here
plt.title('Temperature Trends Over Time')
plt.xticks(rotation=45)
plt.legend()
plt.show()

# %% [markdown]
# #### Task 3: Scatter Plot for Temperature vs. Humidity
# 3. Create a scatter plot to explore the relationship between temperature and humidity.
#    - Use the correct function to create a scatter plot.
#    - Set labels for the axes and include a title.
#
#    **Questions:**
#    - Describe the relationship between temperature and humidity. Is there a correlation?
#    - How would you describe the strength and direction of this relationship?

# %%
import matplotlib.pyplot as plt

# Scatter plot for Temperature vs Humidity
plt.figure(figsize=(10, 5))
plt.scatter(df['Temperature'], df['Humidity'])
plt.xlabel('Temperature(°C)')
plt.ylabel('Humidity')  # Corrected typo here
plt.title('Temperature vs Humidity')
#plt.xticks(rotation=45)
#plt.legend()
plt.show()

# %% [markdown]
# A. There  is no correlation between temperature and humidity

# %% [markdown]
# #### Task 4: Bar Plot for Monthly Precipitation
# 4. Design a bar plot to compare monthly precipitation levels.
#    - Group the data by month and calculate the total precipitation for each month.
#    - Create the bar plot and set appropriate labels and a title.
#
#    **Questions:**
#    - Which month has the highest total precipitation?
#    - Are there any months with significantly lower or higher precipitation levels?

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Converting date column to datetime format and extracting the month
df['Date'] = pd.to_datetime(df['Date'])
df['Month'] = df['Date'].dt.month

# Grouping by month and summing up precipitation
monthly_precipitation = df.groupby('Month')['Precipitation'].sum()

# Bar plot for Monthly Precipitation
plt.figure(figsize=(10, 5))
plt.bar(monthly_precipitation.index, monthly_precipitation.values, color='SkyBlue')
plt.xlabel('Month')
plt.ylabel('Total Precipitation (mm)')  # Corrected typo here
plt.title('Monthly Precipitation Levels')
plt.xticks(ticks=range(1, 13), labels=['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
plt.show()

# %% [markdown]
# #### Task 5: Multi-Panel Figure with Subplots
# 5. Combine the line plot, scatter plot, and bar plot into a multi-panel figure using subplots.
#    - Arrange the plots in a multi-panel layout.
#    - Ensure the plots are clearly labeled for easy comparison.
#
#    **Questions:**
#    - How do the different visualisations complement each other?
#    - What insights can you draw by comparing these visualisations side by side?

# %%
# Put your answer here

import pandas as pd
import matplotlib.pyplot as plt

# Sample data (replace this with your actual data loading code)
df = pd.read_csv("mock_weather_data_seasonal.csv")
df['Date'] = pd.to_datetime(df['Date'])
df['Month'] = df['Date'].dt.month

# Grouping by month and summing up precipitation
monthly_precipitation = df.groupby('Month')['Precipitation'].sum()

# Create a multi-panel figure
fig, axs = plt.subplots(2, 2, figsize=(15, 10), sharex=False, sharey=False)

# Line plot for temperature trends
axs[0, 0].plot(df['Date'], df['Temperature'], label='Temperature', color='blue')
axs[0, 0].set_ylabel('Temperature (°C)')
axs[0, 0].set_title('Temperature Trends Over Time')
axs[0, 0].legend()
axs[0, 0].grid(True)

# Scatter plot for Temperature vs Humidity
axs[0, 1].scatter(df['Temperature'], df['Humidity'], color='red')
axs[0, 1].set_xlabel('Temperature (°C)')
axs[0, 1].set_ylabel('Humidity (%)')
axs[0, 1].set_title('Temperature vs Humidity')
axs[0, 1].grid(True)

# Bar plot for Monthly Precipitation
axs[1, 0].bar(monthly_precipitation.index, monthly_precipitation.values, color='SkyBlue')
axs[1, 0].set_xlabel('Month')
axs[1, 0].set_ylabel('Total Precipitation (mm)')
axs[1, 0].set_title('Monthly Precipitation Levels')
axs[1, 0].set_xticks(range(1, 13))
axs[1, 0].set_xticklabels(['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])

# Hide the fourth subplot (empty)
axs[1, 1].axis('off')

# Adjust layout for better spacing
plt.tight_layout()
plt.show()
